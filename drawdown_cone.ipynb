# %% [markdown]
# # The Boundary Effects on the Drawdown Cone - Image Well Theory

# %% [markdown]
# ## The Image Well Theory
#
# ***The effect of a barrier boundary on the drawdown in a well, as a result of pumping from another well, is the same as though the aquifer were infinite and a like discharging well were located across the real boundary on a perpendicular thereto and at the same distance from the boundary as the real pumping well. For a recharge boundary the principle is the same except that the image well is assumed to be discharging the aquifer instead of pumping from it.***
#
# ### Confined Aquifers
# $$ Q=2\pi Krb\frac{dh}{dr} $$
# $$ \int_{h_1}^{h_2}dh = \frac{Q}{2\pi Kb}\int_{r_1}^{r_2}\frac{dr}{r} $$
# $$ Q=2\pi Kb\left[\frac{h_2-h_1}{\ln(r_2/r_1)}\right] $$
#
# ### Assumptions
# A 2‐ft diameter well penetrates vertically through a confined aquifer 50 ft thick. The well is pumped at 500 gpm for steady-state conditions, $K=0.158~gpm/ft^2$. Take the initial piezometric level as 100 ft above the datum. The drawdown in the well is 49.6 ft
#
# ### Problems:
# 1. Plot the drawdown cone without influence of boundary effects
# 1. Plot the drawdown cone under the influence of a barrier boundary from the right side
# 1. Plot the drawdown cone under the influence of a recharge boundary from the right side

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.plot(r1_list,h1_list,'k-',label='drawdown curve without boundary impact')
plt.axvline(d,label='barrier boundary')
plt.plot(r1_list[:len(s2_list)],img_h2_list,'b--',label="imaginary well's drawdown curve")
plt.plot(r1_list[:r1_list.index(d)],h2_list[:r1_list.index(d)],'r-',label='drawdown curve with barrier boundary')
plt.ylim([0,100])
plt.legend()
plt.title('Drawdown Cone under the Influence of a Barrier Boundary')
plt.xlabel('Distance to the well, ft')
plt.ylabel('Artesian head, ft')
# Out:
# Text(0, 0.5, 'Artesian head, ft')

# %%
plt.plot(r1_list,h1_list,'k-',label='drawdown curve without boundary impact')
plt.axvline(d,label='barrier boundary')
plt.plot(r1_list[:len(s3_list)],img_h3_list,'b--',label="imaginary well's drawdown curve")
plt.plot(r1_list[:r1_list.index(d)],h3_list[:r1_list.index(d)],'r-',label='drawdown curve with recharge boundary')
plt.ylim([0,150])
plt.legend()
plt.title('Drawdown Cone under the Influence of a Recharge Boundary')
plt.xlabel('Distance to the well, ft')
plt.ylabel('Artesian head, ft')
# Out:
# Text(0, 0.5, 'Artesian head, ft')
